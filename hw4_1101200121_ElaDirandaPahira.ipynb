# %% [markdown]
# Tugas Pertemuan 4
# =======
#
#
# Nama : Ela Diranda Pahira
# ----
# NIM    : 1101200121
# ----------
# Kelas : TT-44-06
# ------------------
#
# Soal :
# 1. Create a program to convert hex number into binary number.
# 2. Create a program to convert binary number into hex number.
# 3. Create a program to show shopping list in everyday. The program should also be able to add/delete shopping list item/value
# Tips: for tasks 1 and 2, you can use a dictionary in which the key is the hex number, and the value is the binary number and vice versa.

# %%
jwb = 'Jawaban Nomor 1'
a = jwb.center (120)
print (a)
print (' ')
print ('Mengubah Bilangan Hex ke Bilangan Biner\n')

d = {"0":"0000",
     "1":"0001",
     "2":"0010",
     "3":"0011",
     "4":"0100",
     "5":"0101",
     "6":"0110",
     "7":"0111",
     "8":"1000",
     "9":"1001",
     "A":"1010",
     "B":"1011",
     "C":"1100",
     "D":"1101",
     "E":"1110",
     "F":"1111"}
def hexbiner (d):
    hex = input('Masukkan bilangan hex yang ingin diubah ke bilangan biner : ')
    for i in range (len(d)):
        if hex in (d):
            print ('Hasilnya : ')
            print (hex,'=',d[hex])
            i = input('Apakah anda ingin mengulang lagi (y/n) ?')
            print (' ')
            if i == 'y':
                return hexbiner (d)
            else :
                break
        else :
            print ('Error')
            i = input('Apakah anda ingin mengulang lagi (y/n) ?')
            print (' ')
            if i == 'y':
                return hexbiner (d)
            else :
                break

hexbiner (d)
# Out:
#                                                     Jawaban Nomor 1
#
# Mengubah Bilangan Hex ke Bilangan Biner
#
# Masukkan bilangan hex yang ingin diubah ke bilangan biner : 1
# Hasilnya :
# 1 = 0001
# Apakah anda ingin mengulang lagi (y/n) ?y
#
# Masukkan bilangan hex yang ingin diubah ke bilangan biner : A
# Hasilnya :
# A = 1010
# Apakah anda ingin mengulang lagi (y/n) ?n

# %%
jwb = 'Jawaban Nomor 2'
a = jwb.center (120)
print (a)
print (' ')
print ('Mengubah Bilangan Biner ke Bilangan Hex\n')

d = {"0000":"0",
     "0001":"1",
     "0010":"2",
     "0011":"3",
     "0100":"4",
     "0101":"5",
     "0110":"6",
     "0111":"7",
     "1000":"8",
     "1001":"9",
     "1010":"A",
     "1011":"B",
     "1100":"C",
     "1101":"D",
     "1110":"E",
     "1111":"F"}
def binerhex (d):
    biner = input('Masukkan bilangan biner yang ingin diubah ke bilangan hex : ')
    for i in range (len(d)):
        if biner in (d):
            print ('Hasilnya : ')
            print (biner,'=',d[biner])
            i = input('Apakah anda ingin mengulang lagi (y/n) ?')
            print (' ')
            if i == 'y':
                return binerhex (d)
            else :
                break
        else :
            print ('Error')
            i = input('Apakah anda ingin mengulang lagi (y/n) ?')
            print (' ')
            if i == 'y':
                return binerhex (d)
            else :
                break

binerhex (d)
# Out:
#                                                     Jawaban Nomor 2
#
# Mengubah Bilangan Biner ke Bilangan Hex
#
# Masukkan bilangan biner yang ingin diubah ke bilangan hex : 0110
# Hasilnya :
# 0110 = 6
# Apakah anda ingin mengulang lagi (y/n) ?y
#
# Masukkan bilangan biner yang ingin diubah ke bilangan hex : 1101
# Hasilnya :
# 1101 = D
# Apakah anda ingin mengulang lagi (y/n) ?n

# %%
jwb = 'Jawaban Nomor 3'
a = jwb.center (120)
print (a)

pilih = 'y'
while pilih == 'y':
    print ('List Belanja : ')
    list_menu = ['Buah', 'Daging', 'Keju', 'Sambal']
    print (list_menu)
    print('''
    =======================================================================================================
    Pilihan Menu :
    =======================================================================================================
    1. Menambah Daftar Belanja
    2. Menghapus Daftar Belanja
    =======================================================================================================
    ''')
    print (' ')
    print ('=============================================================================')
    Menu = str(input('Masukkan Pilihan Menu   : '))
    tambah_menu = int (input('Banyak daftar belanja yang ingin ditambah/dihapus : '))
    list_menu = ['Buah', 'Daging', 'Keju', 'Sambal']
    print ('=============================================================================')
    
    if Menu == '1':
        for i in range (tambah_menu):
            nama = input('Masukkan daftar belanja yang Ingin ditambahkan: ')
            list_menu.append(nama)
        print ('Daftar belanja baru : ')
        print (list_menu)
        break
    elif Menu == '2':
        for i in range (tambah_menu):
            hapus = int(input('Masukkan index daftar belanja yang ingin dihapus : '))
            print ('Daftar belanja baru : ')
            list_menu.pop(hapus)
            print (list_menu)
        break
    else : 
        pilih = input ('Pilihan Anda Tidak Tersedia. Mohon Ulangi Lagi y/n : ')
# Out:
#                                                     Jawaban Nomor 3
# List Belanja :
# ['Buah', 'Daging', 'Keju', 'Sambal']
#
# ...
#     Pilihan Menu :
# ...
#     1. Menambah Daftar Belanja
#     2. Menghapus Daftar Belanja
# ...
#
#
# ...
# Masukkan Pilihan Menu   : 1
# Banyak daftar belanja yang ingin ditambah/dihapus : 2
# ...
# Masukkan daftar belanja yang Ingin ditambahkan: Beras
# Masukkan daftar belanja yang Ingin ditambahkan: Mie
# Daftar belanja baru :
# ['Buah', 'Daging', 'Keju', 'Sambal', 'Beras', 'Mie']
