# %% [markdown]
# Tugas Pertemuan 3
# ====================
# Nama : Ela Diranda Pahira
# --------------
# NIM : 1101200121
# ---
# Kelas : TT-44-06
# ---
#
#
# Soal :
# 1. Run this code 10 times (manually / automatically) by setting the num = 50. Write the average value on each iteration.
# 2. Modify the code to count the total number of each accumulation of dice1 and dice2. Run the modified code 10 times by setting    the num = 50. Write each accumulation value on each iteration. Which accumulation value is the highest one?  And which one      is the lowest one?
# 3. Create a source code to sort the number entered by the user (input). Ex: user enter 3, 6, 11, 2, 4, 7, and the code will        sort into 2, 3, 4, 6, 7, 11.
# 4. Create a source code to output the total normal price of the product and the discounted price of the product bought by          customers. The list of product is given as follows:
#    • Vegetables (5000 IDR/kg, disc. 10% if at least 2 kg),
#    • Drinks (10000 IDR/can, disc. 8% if at least 6 cans)
#    • Eggs (20000 IDR/kg, disc. 15% if at least 5kg)
#    • Meats (75000 IDR/kg, disc. 10% if at least 3kg)

# %%
jwb = 'Jawaban Nomor 1'
a = jwb.center (120)
print (a)

i = 1
num = 50
a = 1
total = 0
print ('Masukkan Nilai !')
print (' ')
while (a <= num):
    x=int (input('Nilai ke '+str(i)+' = '))
    i = i + 1
    a = a + 5
    total = total + x
    rata = total / 10
print (' ')
print ('Jumlah    = ', total)
print ('Rata-Rata = ',rata)
# Out:
#                                                     Jawaban Nomor 1
# Masukkan Nilai !
#
# Nilai ke 1 = 1
# Nilai ke 2 = 2
# Nilai ke 3 = 3
# Nilai ke 4 = 4
# Nilai ke 5 = 5
# Nilai ke 6 = 6
# Nilai ke 7 = 7
# Nilai ke 8 = 8
# Nilai ke 9 = 9
# Nilai ke 10 = 10
#
# Jumlah    =  55
# Rata-Rata =  5.5

# %%
jwb = 'Jawaban Nomor 2'
a = jwb.center (120)
print (a)

print ('Dice 1 : ')
for data in range (1, 11):
    if (data%2==0):
        print (data, end = ' ')

print (' ')
print (' ')
print ('Dice 2 : ')
for data in range (1, 11):
    if (data%2 != 0):
        print (data, end = ' ')
        
print ('\n=======================================================================================================================')     

lst = []
n = int(input('Banyak Nilai Dice 1 = '))
print (' ')
for i in range(n):
    nilai = int(input('Masukkan Nilai Dice 1 = '))
    lst.append(nilai)
print('\nNilai Tertinggi di Dice 1 Adalah = ', max(lst))
print('Nilai Terendah di Dice 1 Adalah  = ', min(lst))

print ('\n=======================================================================================================================')

lst = []
n = int(input('Banyak Nilai Dice 2 = '))
print (' ')
for i in range(n):
    nilai = int(input('Masukkan Nilai Dice 2 = '))
    lst.append(nilai)
print('\nNilai Tertinggi di Dice 2 Adalah = ', max(lst))
print('Nilai Terendah di Dice 2 Adalah  = ', min(lst))
# Out:
#                                                     Jawaban Nomor 2
# Dice 1 :
# 2 4 6 8 10
#
# Dice 2 :
# 1 3 5 7 9
# ...
# Banyak Nilai Dice 1 = 5
#
# Masukkan Nilai Dice 1 = 2
# Masukkan Nilai Dice 1 = 4
# Masukkan Nilai Dice 1 = 6
# Masukkan Nilai Dice 1 = 8
# Masukkan Nilai Dice 1 = 10
#
# Nilai Tertinggi di Dice 1 Adalah =  10
# Nilai Terendah di Dice 1 Adalah  =  2
#
# ...
# Banyak Nilai Dice 2 = 5
#
# Masukkan Nilai Dice 2 = 1
# Masukkan Nilai Dice 2 = 3
# Masukkan Nilai Dice 2 = 5
# Masukkan Nilai Dice 2 = 7
# Masukkan Nilai Dice 2 = 9
#
# Nilai Tertinggi di Dice 2 Adalah =  9
# Nilai Terendah di Dice 2 Adalah  =  1

# %%
jwb = 'Jawaban Nomor 3'
a = jwb.center (120)
print (a)

def srt (data):
    for elemen in range (1, len(data)):
        dat = data [elemen]
        i = elemen
        while dat < data [i-1] and i > 0:
            data [i] = data [i-1]
            i =  i-1
        data [i] = dat
        
n = int(input('Banyak Data : '))
i = 1
print (' ')
x = [int(input('Masukkan Data ke '+str(i+1)+ ' : ')) for i in range (n)]
print (' ')
print ('Data Sebelum diurutkan\t: ',x)
srt(x)
print ('Data Setelah di urutkan : ',end=' ')
print (x)
# Out:
#                                                     Jawaban Nomor 3
# Banyak Data : 6
#
# Masukkan Data ke 1 : 3
# Masukkan Data ke 2 : 6
# Masukkan Data ke 3 : 11
# Masukkan Data ke 4 : 2
# Masukkan Data ke 5 : 4
# Masukkan Data ke 6 : 7
#
# Data Sebelum diurutkan	:  [3, 6, 11, 2, 4, 7]
# Data Setelah di urutkan :  [2, 3, 4, 6, 7, 11]

# %%
jwb = 'Jawaban Nomor 4'
a = jwb.center (120)
print (a)

lagi = 'y'
while lagi == 'y':
    print('''
    =======================================================================================================
    List Produk dan Harga :
    =======================================================================================================
    1. Sayur-Mayur\t: Rp. 5.000/1 kg            ***Diskon 10 persen dengan minimal pembelian 2 kg***
    2. Minuman\t\t: Rp. 10.000/1 kaleng      ***Diskon 8 persen dengan minimal pembelian 6 kaleng***
    3. Telur\t\t: Rp. 20.000/1 kg           ***Diskon 15 persen dengan minimal pembelian 5 kg***
    4. Daging\t\t: Rp. 75.000/1kg            ***Diskon 10 persen dengan minimal pembelian 3 kg***
    =======================================================================================================
    ''')
    print (' ')
    print ('===============================================')
    beli = str(input('Masukkan Pilihan Produk   : '))
    banyak = int(input('Banyak Produk yang dibeli : '))
    print ('===============================================')
    
    if beli == '1':
        produk = 'Sayur-Mayur'
        harga = (5000 * banyak)
        x = 5000
        if banyak >= 2:
            diskon = '10 Persen'
            total = int (x - (harga * 0.1 ))
        else:
            diskon = '0'
            total = harga
    elif beli == '2':
        produk = 'Minuman'
        harga = (10000 * banyak)
        x = 10000
        if banyak >= 6:
            diskon = '8 Persen' 
            total = int (x - (harga * 0.08 ))
        else:
            diskon = '0'
            total = harga
    elif beli == '3':
        produk = 'Telur'
        harga = (20000 * banyak)
        x = 20000
        if banyak >= 5:
            diskon = '15 Persen'
            total = int (x - (harga * 0.15 ))
        else:
            diskon = '0'
            total = harga
    elif beli == '4':
        produk = 'Daging'
        harga = (75000 * banyak)
        x = 75000
        if banyak >= 5:
            diskon = '10 Persen'
            total = int (x - (harga * 0.1 ))
        else:
            diskon = '0'
            total = harga
    else:
       lagi = input ('Pilihan Anda Tidak Tersedia. Mohon Ulangi Lagi y/n : ')
    
    print ('Produk yang Akan dibeli')
    print ('===============================================')
    print ('Nama Produk     : ',produk)
    print ('Banyak Produk   : ',banyak)
    print ('Harga\t\t: ',harga)
    print ('Diskon\t\t: ',diskon)
    print ('Jumlah yang Harus dibayar : ',total)
    print ('===============================================')
    
    lagi = input('Ingin Membeli Lagi y/n ? ')
    print (' ')
    print ('-------------------------------------------------Terima Kasih-----------------------------------------------------')
# Out:
#                                                     Jawaban Nomor 4
#
# ...
#     List Produk dan Harga :
# ...
#     1. Sayur-Mayur	: Rp. 5.000/1 kg            ***Diskon 10 persen dengan minimal pembelian 2 kg***
#     2. Minuman		: Rp. 10.000/1 kaleng      ***Diskon 8 persen dengan minimal pembelian 6 kaleng***
#     3. Telur		: Rp. 20.000/1 kg           ***Diskon 15 persen dengan minimal pembelian 5 kg***
#     4. Daging		: Rp. 75.000/1kg            ***Diskon 10 persen dengan minimal pembelian 3 kg***
# ...
#
#
# ...
# Masukkan Pilihan Produk   : 4
# Banyak Produk yang dibeli : 2
# ...
# Produk yang Akan dibeli
# ...
# Nama Produk     :  Daging
# Banyak Produk   :  2
# Harga		:  150000
# Diskon		:  0
# Jumlah yang Harus dibayar :  150000
# ...
# Ingin Membeli Lagi y/n ? n
#
# -------------------------------------------------Terima Kasih-----------------------------------------------------
